# %%
import requests

def generate_completion():
    url = "https://api.euron.one/api/v1/euri/chat/completions"
    
    # ✅ Added the API key placeholder
    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer euri-e28353e711c0facc52e493a355bdadadd980a766dee58db2e52807fdc3c48cc7" 
    }
    
    payload = {
        # ✅ Fixed spelling: "messages"
        "messages": [
            {
                "role": "user",
                "content": "tell me about gen ai"
            }
        ],
        "model": "gpt-4o-mini",
        "max_tokens": 1000,
        # ✅ Fixed spelling: "temperature"
        "temperature": 0.7
    }

    try:
        # Added a timeout for best practice
        response = requests.post(url, headers=headers, json=payload, timeout=30)
        
        # This will raise an exception if the API returns an error code (like 400 or 401)
        response.raise_for_status() 
        
        data = response.json()
        
        # Print just the assistant's reply for a cleaner output
        print("\n🤖 AI Response:")
        print(data["choices"][0]["message"]["content"])
        
    except requests.exceptions.RequestException as e:
        print(f"\n❌ API Error: {e}")
        if response.text:
            print(f"Error Details: {response.text}")

# ✅ CRITICAL: Actually call the function so it runs!
if __name__ == "__main__":
    generate_completion()
# Out:
# 🤖 AI Response:
# Generative AI, often referred to as Gen AI, is a subset of artificial intelligence focused on creating new content, such as text, images, music, and more, by learning from existing data. It employs various techniques, primarily based on machine learning and deep learning, to generate outputs that can resemble human-created content. Here are some key aspects of Generative AI:
#
# ### 1. **How It Works:**
#    - **Training Data:** Generative AI models are trained on large datasets that contain examples of the type of content they will generate. For instance, a model trained on text data might learn grammar, style, and context from books, articles, and other written material.
#    - **Model Types:** Common models include Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and transformer-based models like OpenAI's GPT (Generative Pre-trained Transformer). Each of these models has its own way of generating content.
# ...

# %%
import requests

url = "https://api.euron.one/api/v1/euri/chat/completions"

headers = {
    "Content-Type": "application/json",
    "Authorization": "Bearer euri-e28353e711c0facc52e493a355bdadadd980a766dee58db2e52807fdc3c48cc7"
}

payload = {
    "messages": [{"role": "user", "content": "Hello!"}],
    "model": "gpt-5.3-instant"
}

response = requests.post(url, json=payload, headers=headers)
print(response.json())
# Out:
# {'id': 'chatcmpl-Do9bGM23NlcvpssPHMIacc5IG0RrI', 'object': 'chat.completion', 'created': 1780845674, 'model': 'gpt-5.3-instant', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'Hi! How can I help you today?'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 8, 'completion_tokens': 18, 'total_tokens': 26}}
