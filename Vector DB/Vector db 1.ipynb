# %%
import requests

# 🔧 Changed the endpoint from /chat/completions to /embeddings
url = "https://api.euron.one/api/v1/euri/embeddings"
token = "euri-946116a9b032f6f6d44bae24dc4a558ae160acdd756b7449a759e0a9fa744257"

payload = {
    "input": "My name is Rajesh",
    "model": "text-embedding-3-small"
}

headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

# Print the full JSON response
print(response.json())
# Out:
# {'object': 'list', 'data': [{'object': 'embedding', 'embedding': [-0.00958251953125, -0.054718017578125, -0.058380126953125, -0.0179290771484375, -0.04541015625, 0.00792694091796875, 0.010894775390625, 0.048309326171875, -0.059112548828125, -0.0170745849609375, 0.0276947021484375, 0.006900787353515625, 0.0011444091796875, -0.0190277099609375, 0.04034423828125, -0.022247314453125, -0.0032863616943359375, -0.019805908203125, -0.0224609375, 0.05120849609375, 0.0198974609375, 0.003902435302734375, 0.0435791015625, -0.0026149749755859375, 0.00775909423828125, 0.03125, 0.034912109375, -0.01184844970703125, 0.052764892578125, -0.043487548828125, 0.038482666015625, -0.0260772705078125, 0.02911376953125, 0.00502777099609375, -0.029632568359375, 0.0112152099609375, 0.0011606216430664062, -0.03125, -0.0134735107421875, 0.0239105224609375, -0.0037136077880859375, -0.0048370361328125, 0.04022216796875, 0.048126220703125, 0.006893157958984375, -0.0034046173095703125, -0.0572509765625, -0.032836914
# ...

# %%
result = response.json()

# %%
result['data'][0]['embedding']
# Out:
# [-0.00958251953125,
#  -0.054718017578125,
#  -0.058380126953125,
#  -0.0179290771484375,
#  -0.04541015625,
#  0.00792694091796875,
#  0.010894775390625,
#  0.048309326171875,
#  -0.059112548828125,
#  -0.0170745849609375,
#  0.0276947021484375,
#  0.006900787353515625,
#  0.0011444091796875,
#  -0.0190277099609375,
#  0.04034423828125,
#  -0.022247314453125,
#  -0.0032863616943359375,
#  -0.019805908203125,
#  -0.0224609375,
#  0.05120849609375,
#  0.0198974609375,
#  0.003902435302734375,
#  0.0435791015625,
#  -0.0026149749755859375,
#  0.00775909423828125,
#  0.03125,
#  0.034912109375,
#  -0.01184844970703125,
#  0.052764892578125,
#  -0.043487548828125,
#  0.038482666015625,
#  -0.0260772705078125,
#  0.02911376953125,
#  0.00502777099609375,
#  -0.029632568359375,
#  0.0112152099609375,
#  0.0011606216430664062,
#  -0.03125,
#  -0.0134735107421875,
#  0.0239105224609375,
#  -0.0037136077880859375,
#  -0.0048370361328125,
#  0.04022216796875,
#  0.048126220703125,
# ...

# %%
len (result['data'][0]['embedding'])
# Out:
# 1536

# %%
import requests

# 🔧 Changed the endpoint from /chat/completions to /embeddings
url = "https://api.euron.one/api/v1/euri/embeddings"
token = "euri-946116a9b032f6f6d44bae24dc4a558ae160acdd756b7449a759e0a9fa744257"

payload = {
    "input": "I am from Tripura",
    "model": "text-embedding-3-small"
}

headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

# Print the full JSON response
#print(response.json())

b = response.json()['data'][0]['embedding']

# %%
import requests

# 🔧 Changed the endpoint from /chat/completions to /embeddings
url = "https://api.euron.one/api/v1/euri/embeddings"
token = "euri-946116a9b032f6f6d44bae24dc4a558ae160acdd756b7449a759e0a9fa744257"

payload = {
    "input": "I work as a data analyst",
    "model": "text-embedding-3-small"
}

headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

# Print the full JSON response
#print(response.json())

c = response.json()['data'][0]['embedding']
