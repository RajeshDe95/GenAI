# %%
2+2
# Out:
# 4

# %%
a=2

# %%
a
# Out:
# 2

# %%
type(a)
# Out:
# int

# %%
b=45.56

# %%
type(b)
# Out:
# float

# %%
c='sudh'

# %%
type(c)
# Out:
# str

# %%
f=4+5j

# %%
type(f)
# Out:
# complex

# %%
f.real
# Out:
# 4.0

# %%
f.imag
# Out:
# 5.0

# %%
g=True

# %%
type(g)
# Out:
# bool

# %%
True + False
# Out:
# 1

# %%
h=None

# %%
type(h)
# Out:
# NoneType

# %%
a=10

# %%
id(a)
# Out:
# 140722310792600

# %%
b=a

# %%
id(b)
# Out:
# 140722310792600

# %%
e=(1,2,3)

# %%
type(e)
# Out:
# tuple
